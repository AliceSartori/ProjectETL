# %%
import pandas as pd

# %%
future_file = "Future50.csv"
future_df = pd.read_csv(future_file)
future_df.head()
# Out:
#    Rank   Restaurant          Location           State  Sales YOY_Sales  \
# 0     1   Evergreens           Seattle      Washington     24   130.50%
# 1     2  Clean Juice         Charlotte  North Carolina     44   121.90%
# 2     3     Slapfish  Huntington Beach      California     21    81.00%
# 3     4   Clean Eatz        Wilmington  North Carolina     25    79.70%
# 4     5    Pokeworks            Irvine      California     49    77.10%
#
#    Units YOY_Units  Unit_Volume Franchising
# 0     26   116.70%         1150          No
# 1    105    94.40%          560         Yes
# 2     21    90.90%         1370         Yes
# 3     46    58.60%          685         Yes
# 4     50    56.30%         1210         Yes

# %%
independence_file = "Independence100.csv"
independence_df = pd.read_csv(independence_file)
independence_df.head()
# Out:
#    Rank                           Restaurant       Sales  Average Check  \
# 0     1             Carmine's (Times Square)  39080335.0             40
# 1     2                The Boathouse Orlando  35218364.0             43
# 2     3                     Old Ebbitt Grill  29104017.0             33
# 3     4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4     5             Bryant Park Grill & Cafe  26900000.0             62
#
#          City           State  Meals Served
# 0    New York        New York      469803.0
# 1    Orlando          Florida      820819.0
# 2  Washington  Washington D.C      892830.0
# 3    New York        New York      198500.0
# 4    New York        New York      403000.0

# %%
top_file = "Top250.csv"
top_df = pd.read_csv(top_file)
top_df.head()
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters Unnamed: 8  \
# 0  40412     4.90%  13846    -0.50%          NaN        NaN
# 1  21380     8.60%  15049     3.00%          NaN        NaN
# 2  11320    13.00%   2470     5.00%          NaN        NaN
# 3  11293     9.00%   6766     2.70%          NaN        NaN
# 4  10204     2.70%   7346     0.20%          NaN        NaN
#
#               Segment_Category
# 0       Quick Service & Burger
# 1  Quick Service & Coffee Cafe
# 2      Quick Service & Chicken
# 3      Quick Service & Mexican
# ...

# %%
independence_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           100 non-null    int64
#  1   Restaurant     100 non-null    object
#  2   Sales          100 non-null    float64
#  3   Average Check  100 non-null    int64
#  4   City           100 non-null    object
#  5   State          100 non-null    object
#  6   Meals Served   100 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.6+ KB

# %%
future_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         50 non-null     int64
#  1   Restaurant   50 non-null     object
#  2   Location     50 non-null     object
#  3   State        50 non-null     object
#  4   Sales        50 non-null     int64
#  5   YOY_Sales    50 non-null     object
#  6   Units        50 non-null     int64
#  7   YOY_Units    50 non-null     object
#  8   Unit_Volume  50 non-null     int64
#  9   Franchising  50 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 4.0+ KB

# %%
top_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              250 non-null    int64
#  1   Restaurant        250 non-null    object
#  2   Content           33 non-null     object
#  3   Sales             250 non-null    int64
#  4   YOY_Sales         250 non-null    object
#  5   Units             250 non-null    int64
#  6   YOY_Units         250 non-null    object
#  7   Headquarters      52 non-null     object
#  8   Unnamed: 8        52 non-null     object
#  9   Segment_Category  250 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 19.7+ KB

# %%
top_df.dropna(axis=0, how='all', subset=['Headquarters'], inplace=True)
top_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 65 to 149
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              52 non-null     int64
#  1   Restaurant        52 non-null     object
#  2   Content           1 non-null      object
#  3   Sales             52 non-null     int64
#  4   YOY_Sales         52 non-null     object
#  5   Units             52 non-null     int64
#  6   YOY_Units         52 non-null     object
#  7   Headquarters      52 non-null     object
#  8   Unnamed: 8        52 non-null     object
#  9   Segment_Category  52 non-null     object
# dtypes: int64(3), object(7)
# memory usage: 4.5+ KB

# %%
new_future_df=future_df.convert_dtypes()
new_future_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         50 non-null     Int64
#  1   Restaurant   50 non-null     string
#  2   Location     50 non-null     string
#  3   State        50 non-null     string
#  4   Sales        50 non-null     Int64
#  5   YOY_Sales    50 non-null     string
#  6   Units        50 non-null     Int64
#  7   YOY_Units    50 non-null     string
#  8   Unit_Volume  50 non-null     Int64
#  9   Franchising  50 non-null     string
# dtypes: Int64(4), string(6)
# memory usage: 4.2 KB

# %%
new_top_df=top_df.convert_dtypes()
new_top_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 65 to 149
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              52 non-null     Int64
#  1   Restaurant        52 non-null     string
#  2   Content           1 non-null      string
#  3   Sales             52 non-null     Int64
#  4   YOY_Sales         52 non-null     string
#  5   Units             52 non-null     Int64
#  6   YOY_Units         52 non-null     string
#  7   Headquarters      52 non-null     string
#  8   Unnamed: 8        52 non-null     string
#  9   Segment_Category  52 non-null     string
# dtypes: Int64(3), string(7)
# memory usage: 4.6 KB

# %%
new_independence_df=independence_df.convert_dtypes()
new_independence_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           100 non-null    Int64
#  1   Restaurant     100 non-null    string
#  2   Sales          100 non-null    Int64
#  3   Average Check  100 non-null    Int64
#  4   City           100 non-null    string
#  5   State          100 non-null    string
#  6   Meals Served   100 non-null    Int64
# dtypes: Int64(4), string(3)
# memory usage: 6.0 KB

# %%
new_future_df=new_future_df[['Rank', 'Restaurant', 'Location', 'State']]
new_future_df
# Out:
#     Rank                        Restaurant          Location           State
# 0      1                        Evergreens           Seattle      Washington
# 1      2                       Clean Juice         Charlotte  North Carolina
# 2      3                          Slapfish  Huntington Beach      California
# 3      4                        Clean Eatz        Wilmington  North Carolina
# 4      5                         Pokeworks            Irvine      California
# 5      6                       Playa Bowls            Belmar      New Jersey
# 6      7                  The Simple Greek         Blue Bell    Pennsylvania
# 7      8                         Melt Shop          New York        New York
# 8      9                        Creamistry       Yorba Linda      California
# 9     10              Joella's Hot Chicken        Louisville        Kentucky
# 10    11                     Eggs Up Grill       Spartanburg  South Carolina
# ...

# %%
renamed_future_df=new_future_df.rename(columns={"Location": "City"})
renamed_future_df
# Out:
#     Rank                        Restaurant              City           State
# 0      1                        Evergreens           Seattle      Washington
# 1      2                       Clean Juice         Charlotte  North Carolina
# 2      3                          Slapfish  Huntington Beach      California
# 3      4                        Clean Eatz        Wilmington  North Carolina
# 4      5                         Pokeworks            Irvine      California
# 5      6                       Playa Bowls            Belmar      New Jersey
# 6      7                  The Simple Greek         Blue Bell    Pennsylvania
# 7      8                         Melt Shop          New York        New York
# 8      9                        Creamistry       Yorba Linda      California
# 9     10              Joella's Hot Chicken        Louisville        Kentucky
# 10    11                     Eggs Up Grill       Spartanburg  South Carolina
# ...

# %%
new_independence_df=new_independence_df[['Rank', 'Restaurant', 'City', 'State']]
new_independence_df
# Out:
#     Rank                           Restaurant        City           State
# 0      1             Carmine's (Times Square)    New York        New York
# 1      2                The Boathouse Orlando    Orlando          Florida
# 2      3                     Old Ebbitt Grill  Washington  Washington D.C
# 3      4  LAVO Italian Restaurant & Nightclub    New York        New York
# 4      5             Bryant Park Grill & Cafe    New York        New York
# ..   ...                                  ...         ...             ...
# 95    96                 George's at the Cove    La Jolla      California
# 96    97                            Le Coucou    New York        New York
# 97    98                              Mi Vida  Washington  Washington D.C
# 98    99                               Upland    New York        New York
# 99   100               Virgil's Real Barbecue   Las Vegas          Nevada
#
# [100 rows x 4 columns]

# %%
new_top_df=new_top_df[['Rank', 'Restaurant', 'Headquarters', 'Unnamed: 8']]
new_top_df
# Out:
#      Rank                             Restaurant      Headquarters  \
# 65     66                            Tim Hortons           Toronto
# 66     67               Ruth's Chris Steak House       Winter Park
# 77     78                        Dave & Buster's            Dallas
# 101   102                                 Chuy's            Austin
# 102   103                            O'Charley's         Nashville
# 103   104                         Pollo Tropical             Miami
# 104   105                Maggiano's Little Italy            Dallas
# 105   106                                  Cicis           Coppell
# 106   107                     Long John Silver's        Louisville
# 107   108                  Saltgrass Steak House           Houston
# 108   109                      Chuck E. Cheese's            Irving
# 109   110                            Taco John's          Cheyenne
# 110   111           Texas de Brazil Churrascaria            Dallas
# ...

# %%
new_top_df=new_top_df.rename(columns={"Headquarters": "City", "Unnamed: 8": "State"})
new_top_df
# Out:
#      Rank                             Restaurant              City  \
# 65     66                            Tim Hortons           Toronto
# 66     67               Ruth's Chris Steak House       Winter Park
# 77     78                        Dave & Buster's            Dallas
# 101   102                                 Chuy's            Austin
# 102   103                            O'Charley's         Nashville
# 103   104                         Pollo Tropical             Miami
# 104   105                Maggiano's Little Italy            Dallas
# 105   106                                  Cicis           Coppell
# 106   107                     Long John Silver's        Louisville
# 107   108                  Saltgrass Steak House           Houston
# 108   109                      Chuck E. Cheese's            Irving
# 109   110                            Taco John's          Cheyenne
# 110   111           Texas de Brazil Churrascaria            Dallas
# ...

# %%
Connect to a local database on Postgresql
